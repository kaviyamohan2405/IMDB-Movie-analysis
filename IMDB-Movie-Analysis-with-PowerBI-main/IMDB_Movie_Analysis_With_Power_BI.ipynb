# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from PIL import Image
from io import BytesIO
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# # **Preprocessing**

# %%
df = pd.read_csv('D:/Project/Capstone/career_fair/IMDB-Movie-Analysis-with-PowerBI-main/Dataset/IMDB_Movies_Dataset.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#          actor_1_name                                        movie_title  \
# 0         CCH Pounder                                            Avatar
# 1         Johnny Depp          Pirates of the Caribbean: At World's End
# 2     Christoph Waltz                                           Spectre
# 3           Tom Hardy                             The Dark Knight Rises
# 4         Doug Walker  Star Wars: Episode VII - The Force Awakens    ...
# ...               ...                                                ...
# 5038      Eric Mabius                           Signed Sealed Delivered
# 5039      Natalie Zea                         The Following
# 5040      Eva Boehnke                              A Plague So Pleasant
# 5041        Alan Ruck                                  Shanghai Calling
# 5042      John August                                 My Date with Drew
#
#       num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0              886204                       4834             Wes Studi
# 1              471220                      48350        Jack Davenport
# 2              275868                      11700      Stephanie Sigman
# 3             1144337                     106759  Joseph Gordon-Levitt
# 4                   8                        143                   NaN
# ...               ...                        ...                   ...
# 5038              629                       2283          Crystal Lowe
# 5039            73839                       1753         Sam Underwood
# 5040               38                          0        David Chandler
# 5041             1255                       2386           Eliza Coupe
# 5042             4285                        163              Jon Gunn
#
#       facenumber_in_poster                                      plot_keywords  \
# 0                      0.0             avatar|future|marine|native|paraplegic
# 1                      0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                      1.0                bomb|espionage|sequel|spy|terrorist
# 3                      0.0  deception|imprisonment|lawlessness|police offi...
# 4                      0.0                                                NaN
# ...                    ...                                                ...
# 5038                   2.0             fraud|postal worker|prison|theft|trial
# 5039                   1.0       cult|fbi|hideout|prison escape|serial killer
# 5040                   0.0                                                NaN
# 5041                   5.0                                                NaN
# 5042                   0.0  actress name in title|crush|date|four word tit...
#
#                                         movie_imdb_link num_user_for_reviews  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...                 3054
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...                 1238
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...                  994
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...                 2701
# 4     http://www.imdb.com/title/tt5289954/?ref_=fn_t...
# ...                                                 ...                  ...
# 5038  http://www.imdb.com/title/tt3000844/?ref_=fn_t...                    6
# 5039  http://www.imdb.com/title/tt2071645/?ref_=fn_t...                  359
# 5040  http://www.imdb.com/title/tt2107644/?ref_=fn_t...                    3
# 5041  http://www.imdb.com/title/tt2070597/?ref_=fn_t...                    9
# 5042  http://www.imdb.com/title/tt0378407/?ref_=fn_t...                   84
#
#      language country content_rating       budget  title_year  \
# 0     English     USA          PG-13  237000000.0      2009.0
# 1     English     USA          PG-13  300000000.0      2007.0
# 2     English      UK          PG-13  245000000.0      2015.0
# 3     English     USA          PG-13  250000000.0      2012.0
# 4         NaN     NaN            NaN          NaN         NaN
# ...       ...     ...            ...          ...         ...
# 5038  English  Canada            NaN          NaN      2013.0
# 5039  English     USA          TV-14          NaN         NaN
# 5040  English     USA            NaN       1400.0      2013.0
# 5041  English     USA          PG-13          NaN      2012.0
# 5042  English     USA             PG       1100.0      2004.0
#
#       actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                      936.0         7.9          1.78                 33000
# 1                     5000.0         7.1          2.35                     0
# 2                      393.0         6.8          2.35                 85000
# 3                    23000.0         8.5          2.35                164000
# 4                       12.0         7.1           NaN                     0
# ...                      ...         ...           ...                   ...
# 5038                   470.0         7.7           NaN                    84
# 5039                   593.0         7.5         16.00                 32000
# 5040                     0.0         6.3           NaN                    16
# 5041                   719.0         6.3          2.35                   660
# 5042                    23.0         6.6          1.85                   456
#
# [5043 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          20
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df[['num_critic_for_reviews','director_facebook_likes',
    'actor_3_facebook_likes','actor_1_facebook_likes',
    'num_voted_users','cast_total_facebook_likes',
    'facenumber_in_poster','num_user_for_reviews',
    'actor_2_facebook_likes','movie_facebook_likes']] = df[['num_critic_for_reviews','director_facebook_likes',
                                                            'actor_3_facebook_likes','actor_1_facebook_likes',
                                                            'num_voted_users','cast_total_facebook_likes',
                                                            'facenumber_in_poster','num_user_for_reviews',
                                                            'actor_2_facebook_likes','movie_facebook_likes']].fillna(0)

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews         0
# duration                      15
# director_facebook_likes        0
# actor_3_facebook_likes         0
# actor_2_name                  13
# actor_1_facebook_likes         0
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster           0
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews           0
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes         0
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df = df.dropna().reset_index(drop=True)
df.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 3755  Color   Olivier Assayas                    81.0     110.0
# 3756  Color      Jafar Panahi                    64.0      90.0
# 3757  Color     Shane Carruth                   143.0      77.0
# 3758  Color  Robert Rodriguez                    56.0      81.0
# 3759  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 3755                    107.0                    45.0     Béatrice Dalle
# 3756                    397.0                     0.0  Nargess Mamizadeh
# 3757                    291.0                     8.0     David Sullivan
# 3758                      0.0                     6.0    Peter Marquardt
# 3759                     16.0                    16.0   Brian Herzlinger
#
#       actor_1_facebook_likes      gross                               genres  \
# 3755                   576.0   136007.0                  Drama|Music|Romance
# 3756                     5.0   673780.0                                Drama
# 3757                   291.0   424760.0                Drama|Sci-Fi|Thriller
# 3758                   121.0  2040920.0  Action|Crime|Drama|Romance|Thriller
# 3759                    86.0    85222.0                          Documentary
#
#                  actor_1_name         movie_title  num_voted_users  \
# 3755            Maggie Cheung              Clean              3924
# 3756  Fereshteh Sadre Orafaiy         The Circle              4555
# 3757            Shane Carruth             Primer             72639
# 3758          Carlos Gallardo        El Mariachi             52055
# 3759              John August  My Date with Drew              4285
#
#       cast_total_facebook_likes      actor_3_name  facenumber_in_poster  \
# 3755                        776      Don McKellar                   1.0
# 3756                          5  Mojgan Faramarzi                   0.0
# 3757                        368      Casey Gooden                   0.0
# 3758                        147    Consuelo Gómez                   0.0
# 3759                        163          Jon Gunn                   0.0
#
#                                           plot_keywords  \
# 3755                     jail|junkie|money|motel|singer
# 3756          abortion|bus|hospital|prison|prostitution
# 3757  changing the future|independent film|invention...
# 3758                 assassin|death|guitar|gun|mariachi
# 3759  actress name in title|crush|date|four word tit...
#
#                                         movie_imdb_link num_user_for_reviews  \
# 3755  http://www.imdb.com/title/tt0388838/?ref_=fn_t...                   39
# 3756  http://www.imdb.com/title/tt0255094/?ref_=fn_t...                   26
# 3757  http://www.imdb.com/title/tt0390384/?ref_=fn_t...                  371
# 3758  http://www.imdb.com/title/tt0104815/?ref_=fn_t...                  130
# 3759  http://www.imdb.com/title/tt0378407/?ref_=fn_t...                   84
#
#      language country content_rating   budget  title_year  \
# 3755   French  France              R   4500.0      2004.0
# 3756  Persian    Iran      Not Rated  10000.0      2000.0
# 3757  English     USA          PG-13   7000.0      2004.0
# 3758  Spanish     USA              R   7000.0      1992.0
# 3759  English     USA             PG   1100.0      2004.0
#
#       actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 3755                   133.0         6.9          2.35                   171
# 3756                     0.0         7.5          1.85                   697
# 3757                    45.0         7.0          1.85                 19000
# 3758                    20.0         6.9          1.37                     0
# 3759                    23.0         6.6          1.85                   456

# %%
df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews          object
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   640.0   73058679.0          Action|Adventure|Sci-Fi
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 4     Daryl Sabara                               John Carter
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4           212204                       1873          Polly Walker
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   1.0  alien|american civil war|male nipple|mars|prin...
#
#                                      movie_imdb_link num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                 3054
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                 1238
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                  994
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                 2701
# 4  http://www.imdb.com/title/tt0401729/?ref_=fn_t...                  738
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
# 2  English      UK          PG-13  245000000.0      2015.0
# 3  English     USA          PG-13  250000000.0      2012.0
# 4  English     USA          PG-13  263700000.0      2012.0
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                   632.0         6.6          2.35                 24000

# %%
df['num_critic_for_reviews'] = df['num_critic_for_reviews'].astype(int)
df['duration'] = df['duration'].astype(int)
df['director_facebook_likes'] = df['director_facebook_likes'].astype(int)
df['actor_3_facebook_likes'] = df['actor_3_facebook_likes'].astype(int)
df['actor_1_facebook_likes'] = df['actor_1_facebook_likes'].astype(int)
df['facenumber_in_poster'] = df['facenumber_in_poster'].astype(int)
df['num_user_for_reviews'] = df['num_user_for_reviews'].astype(int)
df['title_year'] = df['title_year'].astype(int)
df['actor_2_facebook_likes'] = df['actor_2_facebook_likes'].astype(int)

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews         int32
# duration                       int32
# director_facebook_likes        int32
# actor_3_facebook_likes         int32
# actor_2_name                  object
# actor_1_facebook_likes         int32
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster           int32
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews           int32
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                     int32
# actor_2_facebook_likes         int32
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
df = df[['movie_imdb_link','color','movie_title','language','title_year','duration',
        'director_name','actor_1_name','actor_2_name','actor_3_name',
        'genres','country','budget','gross','plot_keywords','content_rating',
        'aspect_ratio','imdb_score','num_critic_for_reviews','num_user_for_reviews',
        'num_voted_users','director_facebook_likes','actor_1_facebook_likes',
        'actor_2_facebook_likes','actor_3_facebook_likes','cast_total_facebook_likes',
        'movie_facebook_likes','facenumber_in_poster']]
df.tail()
# Out:
#                                         movie_imdb_link  color  \
# 3755  http://www.imdb.com/title/tt0388838/?ref_=fn_t...  Color
# 3756  http://www.imdb.com/title/tt0255094/?ref_=fn_t...  Color
# 3757  http://www.imdb.com/title/tt0390384/?ref_=fn_t...  Color
# 3758  http://www.imdb.com/title/tt0104815/?ref_=fn_t...  Color
# 3759  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  Color
#
#              movie_title language  title_year  duration     director_name  \
# 3755              Clean    French        2004       110   Olivier Assayas
# 3756         The Circle   Persian        2000        90      Jafar Panahi
# 3757             Primer   English        2004        77     Shane Carruth
# 3758        El Mariachi   Spanish        1992        81  Robert Rodriguez
# 3759  My Date with Drew   English        2004        90          Jon Gunn
#
#                  actor_1_name       actor_2_name      actor_3_name  \
# 3755            Maggie Cheung     Béatrice Dalle      Don McKellar
# 3756  Fereshteh Sadre Orafaiy  Nargess Mamizadeh  Mojgan Faramarzi
# 3757            Shane Carruth     David Sullivan      Casey Gooden
# 3758          Carlos Gallardo    Peter Marquardt    Consuelo Gómez
# 3759              John August   Brian Herzlinger          Jon Gunn
#
#                                    genres country   budget      gross  \
# 3755                  Drama|Music|Romance  France   4500.0   136007.0
# 3756                                Drama    Iran  10000.0   673780.0
# 3757                Drama|Sci-Fi|Thriller     USA   7000.0   424760.0
# 3758  Action|Crime|Drama|Romance|Thriller     USA   7000.0  2040920.0
# 3759                          Documentary     USA   1100.0    85222.0
#
#                                           plot_keywords content_rating  \
# 3755                     jail|junkie|money|motel|singer              R
# 3756          abortion|bus|hospital|prison|prostitution      Not Rated
# 3757  changing the future|independent film|invention...          PG-13
# 3758                 assassin|death|guitar|gun|mariachi              R
# 3759  actress name in title|crush|date|four word tit...             PG
#
#       aspect_ratio  imdb_score  num_critic_for_reviews  num_user_for_reviews  \
# 3755          2.35         6.9                      81                    39
# 3756          1.85         7.5                      64                    26
# 3757          1.85         7.0                     143                   371
# 3758          1.37         6.9                      56                   130
# 3759          1.85         6.6                      43                    84
#
#       num_voted_users  director_facebook_likes  actor_1_facebook_likes  \
# 3755             3924                      107                     576
# 3756             4555                      397                       5
# 3757            72639                      291                     291
# 3758            52055                        0                     121
# 3759             4285                       16                      86
#
#       actor_2_facebook_likes  actor_3_facebook_likes  \
# 3755                     133                      45
# 3756                       0                       0
# 3757                      45                       8
# 3758                      20                       6
# 3759                      23                      16
#
#       cast_total_facebook_likes  movie_facebook_likes  facenumber_in_poster
# 3755                        776                   171                     1
# 3756                          5                   697                     0
# 3757                        368                 19000                     0
# 3758                        147                     0                     0
# 3759                        163                   456                     0

# %%
df = df.drop_duplicates('movie_imdb_link').reset_index(drop=True)

# %%
df.tail()
# Out:
#                                         movie_imdb_link  color  \
# 3655  http://www.imdb.com/title/tt0388838/?ref_=fn_t...  Color
# 3656  http://www.imdb.com/title/tt0255094/?ref_=fn_t...  Color
# 3657  http://www.imdb.com/title/tt0390384/?ref_=fn_t...  Color
# 3658  http://www.imdb.com/title/tt0104815/?ref_=fn_t...  Color
# 3659  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  Color
#
#              movie_title language  title_year  duration     director_name  \
# 3655              Clean    French        2004       110   Olivier Assayas
# 3656         The Circle   Persian        2000        90      Jafar Panahi
# 3657             Primer   English        2004        77     Shane Carruth
# 3658        El Mariachi   Spanish        1992        81  Robert Rodriguez
# 3659  My Date with Drew   English        2004        90          Jon Gunn
#
#                  actor_1_name       actor_2_name      actor_3_name  \
# 3655            Maggie Cheung     Béatrice Dalle      Don McKellar
# 3656  Fereshteh Sadre Orafaiy  Nargess Mamizadeh  Mojgan Faramarzi
# 3657            Shane Carruth     David Sullivan      Casey Gooden
# 3658          Carlos Gallardo    Peter Marquardt    Consuelo Gómez
# 3659              John August   Brian Herzlinger          Jon Gunn
#
#                                    genres country   budget      gross  \
# 3655                  Drama|Music|Romance  France   4500.0   136007.0
# 3656                                Drama    Iran  10000.0   673780.0
# 3657                Drama|Sci-Fi|Thriller     USA   7000.0   424760.0
# 3658  Action|Crime|Drama|Romance|Thriller     USA   7000.0  2040920.0
# 3659                          Documentary     USA   1100.0    85222.0
#
#                                           plot_keywords content_rating  \
# 3655                     jail|junkie|money|motel|singer              R
# 3656          abortion|bus|hospital|prison|prostitution      Not Rated
# 3657  changing the future|independent film|invention...          PG-13
# 3658                 assassin|death|guitar|gun|mariachi              R
# 3659  actress name in title|crush|date|four word tit...             PG
#
#       aspect_ratio  imdb_score  num_critic_for_reviews  num_user_for_reviews  \
# 3655          2.35         6.9                      81                    39
# 3656          1.85         7.5                      64                    26
# 3657          1.85         7.0                     143                   371
# 3658          1.37         6.9                      56                   130
# 3659          1.85         6.6                      43                    84
#
#       num_voted_users  director_facebook_likes  actor_1_facebook_likes  \
# 3655             3924                      107                     576
# 3656             4555                      397                       5
# 3657            72639                      291                     291
# 3658            52055                        0                     121
# 3659             4285                       16                      86
#
#       actor_2_facebook_likes  actor_3_facebook_likes  \
# 3655                     133                      45
# 3656                       0                       0
# 3657                      45                       8
# 3658                      20                       6
# 3659                      23                      16
#
#       cast_total_facebook_likes  movie_facebook_likes  facenumber_in_poster
# 3655                        776                   171                     1
# 3656                          5                   697                     0
# 3657                        368                 19000                     0
# 3658                        147                     0                     0
# 3659                        163                   456                     0

# %%
for i in df:
    print(f"{i}:{df[i].nunique()}")
# Out:
# movie_imdb_link:3660
# color:2
# movie_title:3659
# language:33
# title_year:74
# duration:152
# director_name:1659
# actor_1_name:1430
# actor_2_name:2191
# actor_3_name:2587
# genres:745
# country:45
# budget:359
# gross:3642
# plot_keywords:3660
# content_rating:12
# aspect_ratio:18
# imdb_score:74
# num_critic_for_reviews:525
# num_user_for_reviews:941
# num_voted_users:3614
# director_facebook_likes:394
# actor_1_facebook_likes:714
# actor_2_facebook_likes:856
# actor_3_facebook_likes:882
# cast_total_facebook_likes:3228
# movie_facebook_likes:658
# facenumber_in_poster:19

# %%
df.describe().T
# Out:
#                             count          mean           std      min  \
# title_year                 3660.0  2.002918e+03  9.878914e+00  1927.00
# duration                   3660.0  1.101798e+02  2.271798e+01    37.00
# budget                     3660.0  4.579473e+07  2.287167e+08   218.00
# gross                      3660.0  5.185568e+07  6.931908e+07   162.00
# aspect_ratio               3660.0  2.108885e+00  3.554542e-01     1.18
# imdb_score                 3660.0  6.462760e+00  1.057111e+00     1.60
# num_critic_for_reviews     3660.0  1.650254e+02  1.224643e+02     2.00
# num_user_for_reviews       3660.0  3.310492e+02  4.061941e+02     4.00
# num_voted_users            3660.0  1.047586e+05  1.522282e+05    91.00
# director_facebook_likes    3660.0  8.124036e+02  3.088313e+03     0.00
# actor_1_facebook_likes     3660.0  7.666326e+03  1.560105e+04     0.00
# actor_2_facebook_likes     3660.0  1.982019e+03  4.509914e+03     0.00
# actor_3_facebook_likes     3660.0  7.540959e+02  1.849275e+03     0.00
# cast_total_facebook_likes  3660.0  1.137354e+04  1.910424e+04     0.00
# movie_facebook_likes       3660.0  9.165036e+03  2.149390e+04     0.00
# facenumber_in_poster       3660.0  1.383607e+00  2.054426e+00     0.00
#
#                                    25%          50%          75%           max
# title_year                     1999.00      2004.00      2010.00  2.016000e+03
# duration                         96.00       106.00       120.00  3.300000e+02
# budget                     10000000.00  25000000.00  50000000.00  1.221550e+10
# gross                       7998259.75  29274751.00  66488423.75  7.605058e+08
# aspect_ratio                      1.85         2.35         2.35  1.600000e+01
# imdb_score                        5.90         6.60         7.20  9.300000e+00
# num_critic_for_reviews           76.00       136.00       221.25  8.130000e+02
# num_user_for_reviews            108.00       207.00       394.00  5.060000e+03
# num_voted_users               19123.00     53000.00    126534.50  1.689764e+06
# director_facebook_likes          11.00        61.50       234.00  2.300000e+04
# actor_1_facebook_likes          742.00      1000.00     12000.00  6.400000e+05
# actor_2_facebook_likes          378.00       680.50       973.00  1.370000e+05
# actor_3_facebook_likes          193.75       434.00       689.25  2.300000e+04
# cast_total_facebook_likes      1884.50      3983.50     16091.00  6.567300e+05
# movie_facebook_likes              0.00       209.00     11000.00  3.490000e+05
# facenumber_in_poster              0.00         1.00         2.00  4.300000e+01

# %%
df.to_csv('IMDB_Movies.csv', index=False)

# %% [markdown]
# # **Data Analytics Tasks**

# %%
df = pd.read_csv('D:/Project/Capstone/career_fair/IMDB-Movie-Analysis-with-PowerBI-main/Dataset/IMDB_Movies.csv')
df
# Out:
#                                         movie_imdb_link  color  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  Color
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...  Color
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...  Color
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...  Color
# 4     http://www.imdb.com/title/tt0401729/?ref_=fn_t...  Color
# ...                                                 ...    ...
# 3656  http://www.imdb.com/title/tt0388838/?ref_=fn_t...  Color
# 3657  http://www.imdb.com/title/tt0255094/?ref_=fn_t...  Color
# 3658  http://www.imdb.com/title/tt0390384/?ref_=fn_t...  Color
# 3659  http://www.imdb.com/title/tt0104815/?ref_=fn_t...  Color
# 3660  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  Color
#
#                                     movie_title language  title_year  \
# 0                                       Avatar   English        2009
# 1     Pirates of the Caribbean: At World's End   English        2007
# 2                                      Spectre   English        2015
# 3                        The Dark Knight Rises   English        2012
# 4                                  John Carter   English        2012
# ...                                         ...      ...         ...
# 3656                                     Clean    French        2004
# 3657                                The Circle   Persian        2000
# 3658                                    Primer   English        2004
# 3659                               El Mariachi   Spanish        1992
# 3660                         My Date with Drew   English        2004
#
#       duration      director_name             actor_1_name       actor_2_name  \
# 0          178      James Cameron              CCH Pounder   Joel David Moore
# 1          169     Gore Verbinski              Johnny Depp      Orlando Bloom
# 2          148         Sam Mendes          Christoph Waltz       Rory Kinnear
# 3          164  Christopher Nolan                Tom Hardy     Christian Bale
# 4          132     Andrew Stanton             Daryl Sabara    Samantha Morton
# ...        ...                ...                      ...                ...
# 3656       110    Olivier Assayas            Maggie Cheung     Béatrice Dalle
# 3657        90       Jafar Panahi  Fereshteh Sadre Orafaiy  Nargess Mamizadeh
# 3658        77      Shane Carruth            Shane Carruth     David Sullivan
# 3659        81   Robert Rodriguez          Carlos Gallardo    Peter Marquardt
# 3660        90           Jon Gunn              John August   Brian Herzlinger
#
#               actor_3_name                               genres country  \
# 0                Wes Studi      Action|Adventure|Fantasy|Sci-Fi     USA
# 1           Jack Davenport             Action|Adventure|Fantasy     USA
# 2         Stephanie Sigman            Action|Adventure|Thriller      UK
# 3     Joseph Gordon-Levitt                      Action|Thriller     USA
# 4             Polly Walker              Action|Adventure|Sci-Fi     USA
# ...                    ...                                  ...     ...
# 3656          Don McKellar                  Drama|Music|Romance  France
# 3657      Mojgan Faramarzi                                Drama    Iran
# 3658          Casey Gooden                Drama|Sci-Fi|Thriller     USA
# 3659        Consuelo Gómez  Action|Crime|Drama|Romance|Thriller     USA
# 3660              Jon Gunn                          Documentary     USA
#
#            budget        gross  \
# 0     237000000.0  760505847.0
# 1     300000000.0  309404152.0
# 2     245000000.0  200074175.0
# 3     250000000.0  448130642.0
# 4     263700000.0   73058679.0
# ...           ...          ...
# 3656       4500.0     136007.0
# 3657      10000.0     673780.0
# 3658       7000.0     424760.0
# 3659       7000.0    2040920.0
# 3660       1100.0      85222.0
#
#                                           plot_keywords content_rating  \
# 0                avatar|future|marine|native|paraplegic          PG-13
# 1     goddess|marriage ceremony|marriage proposal|pi...          PG-13
# 2                   bomb|espionage|sequel|spy|terrorist          PG-13
# 3     deception|imprisonment|lawlessness|police offi...          PG-13
# 4     alien|american civil war|male nipple|mars|prin...          PG-13
# ...                                                 ...            ...
# 3656                     jail|junkie|money|motel|singer              R
# 3657          abortion|bus|hospital|prison|prostitution      Not Rated
# 3658  changing the future|independent film|invention...          PG-13
# 3659                 assassin|death|guitar|gun|mariachi              R
# 3660  actress name in title|crush|date|four word tit...             PG
#
#       aspect_ratio  imdb_score  num_critic_for_reviews  num_user_for_reviews  \
# 0             1.78         7.9                     723                  3054
# 1             2.35         7.1                     302                  1238
# 2             2.35         6.8                     602                   994
# 3             2.35         8.5                     813                  2701
# 4             2.35         6.6                     462                   738
# ...            ...         ...                     ...                   ...
# 3656          2.35         6.9                      81                    39
# 3657          1.85         7.5                      64                    26
# 3658          1.85         7.0                     143                   371
# 3659          1.37         6.9                      56                   130
# 3660          1.85         6.6                      43                    84
#
#       num_voted_users  director_facebook_likes  actor_1_facebook_likes  \
# 0              886204                        0                    1000
# 1              471220                      563                   40000
# 2              275868                        0                   11000
# 3             1144337                    22000                   27000
# 4              212204                      475                     640
# ...               ...                      ...                     ...
# 3656             3924                      107                     576
# 3657             4555                      397                       5
# 3658            72639                      291                     291
# 3659            52055                        0                     121
# 3660             4285                       16                      86
#
#       actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                        936                     855
# 1                       5000                    1000
# 2                        393                     161
# 3                      23000                   23000
# 4                        632                     530
# ...                      ...                     ...
# 3656                     133                      45
# 3657                       0                       0
# 3658                      45                       8
# 3659                      20                       6
# 3660                      23                      16
#
#       cast_total_facebook_likes  movie_facebook_likes  facenumber_in_poster
# 0                          4834                 33000                     0
# 1                         48350                     0                     0
# 2                         11700                 85000                     1
# 3                        106759                164000                     0
# 4                          1873                 24000                     1
# ...                         ...                   ...                   ...
# 3656                        776                   171                     1
# 3657                          5                   697                     0
# 3658                        368                 19000                     0
# 3659                        147                     0                     0
# 3660                        163                   456                     0
#
# [3661 rows x 28 columns]
